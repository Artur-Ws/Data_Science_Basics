# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Datasets/Redmi Fuel Band Record Tracker (Fitbit Dataset)/Activity_Dataset_V1.csv')

# %%
df.describe()
# Out:
#         Unnamed: 0     distance         time     calories  total_steps  \
# count  1000.000000  1000.000000  1000.000000  1000.000000   554.000000
# mean    499.500000     5.243620    71.166000   286.310000  4081.119134
# std     288.819436     2.649774    29.341359   156.278511  1865.429141
# min       0.000000     1.000000    20.000000    10.000000  1571.000000
# 25%     249.750000     2.800000    45.000000   155.750000  2790.000000
# 50%     499.500000     5.105000    71.000000   290.500000  3444.000000
# 75%     749.250000     7.542500    97.000000   415.250000  5028.000000
# max     999.000000     9.990000   120.000000   550.000000  7618.000000
#
#          avg_speed  avg_cadence  max_cadence  avg_heart_rate  max_heart_rate  \
# count  1000.000000  1000.000000  1000.000000     1000.000000     1000.000000
# mean     19.765780   107.457870   199.821910      116.282000      136.655000
# std      10.871037    54.312209    85.397007       20.573679       39.739416
# ...

# %%
df['cal/dist ratio'] = df['calories'] / df['distance']

# %%
df[df['cal/dist ratio']<20].describe()
# Out:
#        Unnamed: 0    distance        time    calories  total_steps  \
# count  178.000000  178.000000  178.000000  178.000000    96.000000
# mean   545.106742    6.916966   72.898876   71.685393  4051.468750
# std    288.386873    2.249840   30.627725   45.638990  1945.611158
# min      0.000000    1.300000   20.000000   10.000000  1571.000000
# 25%    323.250000    5.460000   42.000000   34.000000  2790.000000
# 50%    567.500000    7.470000   78.000000   63.000000  3444.000000
# 75%    784.750000    8.707500   99.000000  102.500000  5028.000000
# max    998.000000    9.980000  120.000000  188.000000  7618.000000
#
#         avg_speed  avg_cadence  max_cadence  avg_heart_rate  max_heart_rate  \
# count  178.000000   178.000000   178.000000      178.000000      178.000000
# mean    19.810000   109.221292   190.050393      116.370787      137.342697
# std     10.931365    54.476666    87.985294       21.362889       40.092273
# ...
